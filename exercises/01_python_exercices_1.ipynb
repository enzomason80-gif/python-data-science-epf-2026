# %% [markdown]
# # Python for Data Science
#
# ## Notebook 02 — Apprentissage des structures de données classiques
#
# Objectifs de ce notebook :
#
# - Reprendre les bases de Python
# - Se focaliser sur les structures de données classiques
# - Apprendre à manipuler listes, dictionnaires, tuples, chaines et ensembles
#
# Une fois ces exercices terminés, on pourra considérer que la partie du cours dédiée à l'apprentissage de ces structures de données classiques est terminée, et le prochain cours sera dédié au début de l'apprentissage orienté data science (numpy, etc.)
#
# ## Un contrôle de connaissances sur ces structures de données simples sera effectué pendant la première heure du cours du mardi 7 avril après-midi (13h30 - 14h30) ##

# %% [markdown]
# ## Listes
#
# Pour cette partie, nous allons nous appuyer sur ce tutoriel : https://www.geeksforgeeks.org/python/python-lists/
#
# ### Exercice 1 - Création et affichage
#
# Crée une liste contenant 5 nombres et affiche-la.

# %% [markdown]
# ### Exercice 2 - Accès aux éléments
#
# Avec la liste suivante :
#
# - Affiche le premier élément
# - Affiche le dernier élément

# %%
fruits = ["apple", "banana", "cherry"]

# %% [markdown]
# ### Exercice 3 - Modification
#
# Modifie la liste suivante pour remplacer "banana" par "orange" :

# %%
fruits = ["apple", "banana", "cherry"]

# %% [markdown]
# ### Exercice 4 - Ajouter des éléments
#
# À partir de la liste suivante :
#
# - Ajoute 4 à la fin
# - Ajoute 0 au début

# %%
numbers = [1, 2, 3]

# %% [markdown]
# ### Exercice 5 - Supprimer des éléments
#
# À partir de la liste suivante :
#
# - Supprime 20
# - Supprime le dernier élément

# %%
numbers = [10, 20, 30, 40]

# %% [markdown]
# ### Exercice 6 - Longueur d’une liste
#
# Crée une liste et affiche le nombre d’éléments

# %% [markdown]
# ### Exercice 7 - Parcours simple
#
# Affiche tous les éléments de la liste suivante

# %%
numbers = [1, 2, 3, 4, 5]

# %% [markdown]
# ### Exercice 8 - Somme des éléments
#
# Calcule la somme de tous les nombres dans la liste suivante

# %%
numbers = [1, 2, 3, 4, 5]

# %% [markdown]
# ### Exercice 9 - Trouver le maximum
#
# Trouve le plus grand nombre dans la liste suivante sans utiliser max()

# %%
numbers = [12, 7, 25, 3, 18]

# %% [markdown]
# ### Exercice 10 - Filtrer les nombres pairs
#
# À partir de la liste suivante, crée une nouvelle liste contenant uniquement les nombres pairs

# %%
numbers = [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Exercice 11 - Inverser une liste
#
# Inverse la liste suivante sans utiliser reverse()

# %%
numbers = [1, 2, 3, 4, 5]

# %% [markdown]
# ### Exercice 12 - Compter les occurrences
#
# Compte combien de fois l'élément "2" apparaît dans la liste suivante. Trouve une méthode générale qui fonctionne pour n'importe quel élément d'une liste.

# %%
numbers = [1, 2, 2, 3, 2]

# %% [markdown]
# ### Exercice 13 - Liste sans doublons
#
# Supprime les doublons de la liste suivante

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]

# %% [markdown]
# ### Exercice 14 - Fusion de listes
#
# Fusionne les deux listes suivantes sans utiliser +

# %%
liste1 = [1, 2, 3]
liste2 = [4, 5, 6]

# %% [markdown]
# ### Exercice 15 - Mini-projet
#
# Crée un programme qui :
#
# 1.	Demande à l’utilisateur d’entrer 5 nombres
# 2.	Les stocke dans une liste
# 3.	Affiche :
#
# - la somme
# - la moyenne
# - le plus grand nombre

# %% [markdown]
# ## Dictionnaires
#
# Pour cette partie, nous allons nous appuyer sur ce tutoriel : www.geeksforgeeks.org/python/python-dictionary/
#
# ### Exercice 1
#
# Crée un dictionnaire etudiant contenant :
#
# - "nom" : "Lina"
# - "age" : 21
# - "ville" : "Paris"
#
# Avec et sans utiliser dict()
#
# Affiche ensuite le dictionnaire

# %% [markdown]
# ### Exercice 2
#
# À partir du dictionnaire suivant :
#
# - Affiche la valeur associée à "nom" avec []
# - Affiche la valeur associée à "age" avec get()

# %%
animal = {"espece": "chat", "nom": "Milo", "age": 3}

# %% [markdown]
# ### Exéercice 3 - Différence entre [] et get()
#
# À partir du dictionnaire suivant :
#
# 1. Essaie d’accéder à la clé "ville" avec []
# 2. Essaie avec get("ville")
# 3. Essaie avec get("ville", "Inconnue")

# %%
personne = {"nom": "Sara", "age": 25}

# %% [markdown]
# ### Exercice 4 - Ajouter une nouvelle paire clé-valeur
#
# À partir du dictionnaire suivant, ajoute la clé "annee" avec la valeur 2022, puis affiche le dictionnaire

# %%
voiture = {"marque": "Toyota", "modele": "Yaris"}

# %% [markdown]
# ### Exercice 5 - Mettre à jour une valeur
#
# À partir du dictionnaire suivant, modifie la note de maths pour mettre 16

# %%
notes = {"maths": 12, "anglais": 15}

# %% [markdown]
# ### Exercice 6 - Supprimer une clé avec del
#
# Supprime la clé "actif" du dictionnaire suivant puis affiche le résultat

# %%
compte = {"id": 101, "nom": "Alice", "actif": True}

# %% [markdown]
# ### Exercice 7 - Supprimer avec pop()
#
# À partir du dictionnaire suivant :
#
# 1. Supprime "genre" avec pop()
# 2. Stocke la valeur supprimée dans une variable
# 3. Affiche la variable puis le dictionnaire

# %%
film = {"titre": "Inception", "annee": 2010, "genre": "SF"}

# %% [markdown]
# ### Exercice 8 - popitem()
#
# Crée un dictionnaire avec au moins 4 éléments, puis utilise popitem() pour retirer le dernier élément inséré. Affiche :
#
# - l’élément retiré
# - le dictionnaire final

# %% [markdown]
# ### Exercice 9 - Vider un dictionnaire
#
# Vide complètement le dictionnaire suivant :

# %%
panier = {"pommes": 4, "bananes": 6, "oranges": 2}

# %% [markdown]
# ### Exercice 10 - Parcourir les clés
#
# Affiche uniquement les clés du dictionnaire suivant :

# %%
pays = {"France": "Paris", "Italie": "Rome", "Espagne": "Madrid"}

# %% [markdown]
# ### Exercice 11 - Parcourir les valeurs
#
# Reprends le dictionnaire précédent et affiche uniquement les valeurs

# %% [markdown]
# ### Exercice 12 - Parcourir les couples clés/valeurs
#
# Avec le même dictionnaire, affiche :
#
# France -> Paris
# Italie -> Rome
# Espagne -> Madrid

# %% [markdown]
# ### Exercice 13 - Dictionnaire imbriqué
#
# Créé un dictionnaire classe qui contient deux élèves, le premier s'appelle Emma a une moyenne de 17, le second s'appelle Lucas et a une moyenne de 15
#
# 1. Affiche le nom du premier élève
# 2. Affiche la note du second

# %% [markdown]
# ### Exercice 14 - Compter des occurrences
#
# Écris un programme qui prend la liste suivante et construit un dictionnaire donnant le nombre d’occurrences de chaque mot

# %%
mots = ["chat", "chien", "chat", "oiseau", "chien", "chat"]

# %% [markdown]
# ### Exercice 15 - Inverser un dictionnaire simple
#
# À partir du dictionnaire suivant, crée un nouveau dictionnaire où les clés deviennent les valeurs et inversement

# %%
d = {"a": 1, "b": 2, "c": 3}

# %% [markdown]
# ### Exercice 16 - Filtrer un dictionnaire
#
# À partir du dictionnaire suivant, crée un nouveau dictionnaire contenant seulement les élèves ayant une note supérieure ou égale à 10

# %%
notes = {"Lina": 14, "Tom": 9, "Sara": 17, "Noah": 8}

# %% [markdown]
# ### Exercice 17 - Mini annuaire
#
# Crée un dictionnaire annuaire avec plusieurs noms associés à des numéros, puis :
#
# 1. Affiche le numéro d’une personne
# 2. Ajoute une nouvelle personne
# 3. Modifie un numéro
# 4. Supprime une entrée
# 5. Affiche tout l’annuaire proprement avec une boucle

# %% [markdown]
# ### Exercice 18 - Gestion de stock
#
# À partir du dictionnaire suivant, écris un programme qui :
#
# 1. ajoute 4 pommes
# 2. retire 2 bananes
# 3. affiche le stock final
# 4. affiche le produit ayant le stock le plus faible

# %%
stock = {"pommes": 10, "poires": 5, "bananes": 8}

# %% [markdown]
# ### Exercice 19 - Bilan
#
# Crée un dictionnaire représentant un livre avec :
#
# - titre
# - auteur
# - année
# - genre
# - note
#
# Puis :
#
# 1. affiche le titre
# 2. modifie la note
# 3. ajoute une clé "lu" avec True
# 4. supprime "genre"
# 5. affiche toutes les paires clé/valeur

# %% [markdown]
# ## Les tuples
#
# Pour cette partie, nous allons nous appuyer sur ce tutoriel : https://www.geeksforgeeks.org/python/python-tuples/
#
# ### Exercice 1 - Créer des tuples
#
# Crée les tuples suivants :
#
# 1. un tuple vide
# 2. un tuple contenant "Python" et "Tuple"
# 3. un tuple créé à partir de la liste de nombre 10, 20 et 30
# 4. un tuple créé à partir de la chaîne "chat"

# %% [markdown]
# ### Exercice 2 - Types mélangés
#
# Crée un tuple nommé infos contenant :
#
# - un entier
# - une chaîne de caractères
# - un booléen
# - une liste
# - un dictionnaire

# %% [markdown]
# ### Exercice 3 - Type et taille
#
# À partir du tuple suivant :
#
# 1. affiche le type de t
# 2. affiche sa longueur

# %%
t = (4, 8, 15, 16, 23, 42)

# %% [markdown]
# ### Exercice 4 - Indexation
#
# À partir du tuple suivant :
#
# 1. affiche le premier élément
# 2. affiche le troisième élément
# 3. affiche le dernier élément
# 4. affiche l’avant-dernier élément

# %%
t = ("a", "b", "c", "d", "e")

# %% [markdown]
# ### Exercice 5 - Slicing
#
# À partir du tuple suivant, affiche :
#
# 1. les 3 premiers éléments
# 2. les éléments de l’indice 2 à 4
# 3. tous les éléments sauf le premier
# 4. le tuple inversé

# %% [markdown]
# ### Exercice 6 - Concaténation
#
# À partir des deux tuples suivants, concatène-les dans un nouveau tuple t3 et affiche t3

# %%
t1 = (1, 2, 3)
t2 = ("a", "b")

# %% [markdown]
# ### Exercice 7 - Répétition
#
# Crée un tuple qui répète "go" 4 fois

# %% [markdown]
# ### Exercicer 8 - Test d'une propriété
#
# Dans le tuple suivant, remplace 20 par 99 : que se passe-t-il et pourquoi ?

# %%
t = (10, 20, 30)

# %% [markdown]
# ### Exercice 9 - Déballage simple
#
# Déballe le tuple suivant dans trois variables et affiche-les une par une

# %%
t = ("Alice", 22, "Paris")

# %% [markdown]
# ### Exercice 10 - Déballage
#
# À partir du tuple suivant :
#
# 1. place le premier élément dans a
# 2. place le dernier dans b
# 3. récupère tous les éléments du milieu dans milieu
#
# Puis affiche les trois variables

# %%
t = (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ### Exercice 11 - Prédire la sortie
#
# Indique ce qui sera affiché à l'exécution du code suivant :

# %% [raw]
# t = tuple("code")
# print(t[1])
# print(t[1:3])
# print(t[::-1])

# %% [markdown]
# ### Exercice 12 - Vrai ou faux
#
# Dis si chaque affirmation est vraie ou fausse :
#
# 1. Un tuple peut contenir plusieurs types de données
# 2. On peut supprimer un élément précis d’un tuple avec del t[1]
# 3. tuple("abc") donne ("a", "b", "c")
# 4. Un tuple est modifiable comme une liste
# 5. On peut concaténer deux tuples avec +

# %% [markdown]
# ### Exercice 13 - Compter un élément
#
# Compte combien de fois 2 apparaît dans le tuple suivant :

# %%
t = (1, 2, 3, 2, 4, 2, 5)

# %% [markdown]
# ### Exercice 14 - Trouver une position
#
# Trouve l’indice de la première occurrence de "blue" dans le tuple suivant :

# %%
t = ("red", "blue", "green", "blue")

# %% [markdown]
# ### Exercice 15 - Convertir une liste en tuple
#
# Écris un programme qui :
#
# 1. demande à l’utilisateur 4 nombres
# 2. les stocke d’abord dans une liste
# 3. convertit cette liste en tuple
# 4. affiche le tuple final

# %% [markdown]
# ### Exercice 16 - Extraire des informations
#
# À partir du tuple suivant, génère une phrase qui présente l'étudiant :

# %%
etudiant = ("Martin", 19, "Lyon", "Informatique")

# %% [markdown]
# ### Exercice 17 - Mini-analyse d’un tuple
#
# À partir du tuple suivant, écris un programme qui affiche :
#
# 1. la longueur du tuple
# 2. le premier élément
# 3. le dernier élément
# 4. le tuple inversé
# 5. le nombre de fois où 7 apparaît
# 6. l’indice de la première occurrence de 12

# %%
t = (12, 7, 19, 7, 3, 12, 8)

# %% [markdown]
# ## Les chaînes
#
# Pour cette partie, nous allons nous appuyer sur ce tutoriel : https://www.geeksforgeeks.org/python/python-string/
#
# ### Exercice 1 - Créer et afficher
#
# 1. Crée une variable contenant ton prénom
# 2. Affiche-la avec print()

# %% [markdown]
# ### Exercice 2 - Longueur d’une chaîne
#
# Écris un programme qui affiche la longueur de "Python"

# %% [markdown]
# ### Exercice 3 - Concaténation
#
# Combine "Bonjour" et " monde" pour afficher "Bonjour monde"

# %% [markdown]
# ### Exercice 4 - Accès aux caractères
#
# Affiche le premier caractère et le dernier caractère de "Programmation"

# %% [markdown]
# ### Exercice 5 - Chaîne multi-lignes
#
# Crée une chaîne sur plusieurs lignes

# %% [markdown]
# ### Exercice 6 - Extraire une sous-chaîne
#
# À partir de "Hello Python", affiche "Hello"

# %% [markdown]
# ### Exercice 7 - Inverser une chaîne
#
# Sans boucle, inverse "Python"

# %% [markdown]
# ### Exercice 8 - Slicing avec pas
#
# Affiche un caractère sur deux dans "abcdef"

# %% [markdown]
# ### Exercice 9 - Index négatif
#
# 1. Affiche les 3 derniers caractères de "ordinateur"

# %% [markdown]
# ### Exercice 10 - Majuscules
#
# Transforme "python" en majuscules

# %% [markdown]
# ### Exercice 11 - Première lettre en majuscule
#
# Transforme "bonjour" en "Bonjour"

# %% [markdown]
# ### Exercice 12 - Remplacer du texte
#
# Remplace "chat" par "chien" dans "mon chat dort"

# %% [markdown]
# ### Exercice 13 - 	Compter les occurrences
#
# Compte combien de fois "a" apparaît dans "banana"

# %% [markdown]
# ### Exercice 14 - Palindrome
#
# Vérifie si "radar" est un palindrome

# %% [markdown]
# ### Exercice 15 - Compter les voyelles
#
# Compte le nombre de voyelles dans la phrase suivante : "Bonjour tout le monde"

# %% [markdown]
# ### Exercice 16 - Supprimer les espaces
#
# Supprime tous les espaces de "Bonjour tout le monde"

# %% [markdown]
# ### Exercice 17 - Trouver un mot
#
# Vérifie si "python" est présent dans "j'apprends à coder en python"

# %% [markdown]
# ### Exercice 18 - Anagramme
#
# Vérifie si "listen" et "silent" sont des anagrammes

# %% [markdown]
# ### Exercice 19 - Mot le plus long
#
# Trouve le mot le plus long dans la phrase suivante : "Python est un langage très puissant"

# %% [markdown]
# ### Exercice 20 - Compter les mots
#
# Compte le nombre de mots dans la phrase suivante : "Je découvre les chaînes en Python"

# %% [markdown]
# ### Exercice 21 - Encoder une chaîne
#
# À partir de la chaîne suivante, substitue à chaque lettre celle qui la suit dans l’ordre alphabétique :

# %%
texte = "abcxyz"

# %% [markdown]
# ### Exercice 22 - Transformer une phrase en liste
#
# Convertis "Bonjour tout le monde" en une liste qui contient chacun de ses mots

# %% [markdown]
# ### Exercice 23 - Supprimer les doublons
#
# Supprime les lettres répétées dans le mot "programming"

# %% [markdown]
# ## Les ensembles
#
# Pour cette partie, nous allons nous appuyer sur ce tutoriel : https://www.geeksforgeeks.org/python/python-sets/
#
# ### Exercice 1 - Créer un ensemble
#
# Crée un ensemble contenant les valeurs 1, 2, 3 et 4 puis affiche-le

# %% [markdown]
# ### Exercice 2 - Une propriété des ensembles
#
# 1. Crée un ensemble à partir de la liste [1, 2, 2, 3, 4, 4, 5]
# 2. Affiche le résultat et explique ce qui s’est passé

# %% [markdown]
# ### Exercice 3 - À partir d'une chaîne
#
# 1. Crée un ensemble à partir de la chaîne "python"
# 2. Affiche le résultat : combien d’éléments contient-il ?

# %% [markdown]
# ### Exercice 4 - Vérifier l’appartenance
#
# À partir de l'ensemble suivant, écris un programme qui vérifie si "banane" est présent, fais aussi le test avec "kiwi"

# %%
s = {"pomme", "banane", "orange"}

# %% [markdown]
# ### Exercice 5 - Ajouter un élément
#
# Ajoute 4 à l'ensemble suivant :

# %%
s = {1, 2, 3}

# %% [markdown]
# ### Exercice 6 - Ajouter plusieurs éléments
#
# Reprends l'ensemble précédent et ajoute d'un coup les nombre 4, 5 et 6

# %% [markdown]
# ### Exercice 7 - Parcourir un set
#
# Crée un ensemble qui contient trois animaux et affiche ensuite chaque élément de l'ensemble

# %% [markdown]
# ### Exercice 8
#
# Que va donner le code suivant et pourquoi :

# %% [raw]
# s = {10, 20, 30}
# print(s[0])

# %% [markdown]
# ### Exercice 9 - Suppression
#
# Supprime 3 de l'ensemble suivant :

# %%
s = {1, 2, 3, 4, 5}

# %% [markdown]
# ### Exercice 10 - Test de deux méthodes
#
# Reprends l'ensemble précédent et tente d'enlever l'élément 10 avec la méthode remove puis la méthode discard : que se passe-t-il et pourquoi ?

# %% [markdown]
# ### Exercice 11 - Méthode pop
#
# Crée un ensemble {1, 2, 3, 4, 5}, utilise pop puis affiche :
#
# - la valeur retirée
# - le contenu restant du set

# %% [markdown]
# ### Exercice 12 - Méthode clear
#
# Crée un ensemble non vide, vide-le complètement avec clear puis affiche-le

# %% [markdown]
# ### Exercice 13 - Convertir une liste
#
# Transforme la liste [5, 5, 1, 2, 2, 3, 4, 4] en ensemble

# %% [markdown]
# ### Exercice 14 - Convertir un tuple
#
# Transforme le tuple ("rouge", "bleu", "rouge", "vert") en ensemble

# %% [markdown]
# ### Exercice 15 - Convertir un dictionnaire
#
# Convertis le dictionnaire suivant en ensemble : quel est le résultat ? Pourquoi ?

# %%
d = {"a": 1, "b": 2, "c": 3}

# %% [markdown]
# ### Exercice 16 - Créer un frozenset
#
# Crée un frozenset contenant 1, 2, 3, 4

# %% [markdown]
# ### Exercice 17 - Comparer set et frozenset
#
# Essaie d’ajouter 4 à chacun des ensembles suivants : que constates-tu ?

# %%
s = {1, 2, 3}
fs = frozenset([1, 2, 3])

# %% [markdown]
# ### Exercice 18 -  Corriger le code
#
# Pourquoi le code pose-t-il problème ? Corrige-le

# %%
s = {}
s.add(1)
print(s)

# %% [markdown]
# ### Exercice 19 - Objet non hashable
#
# Crée un ensemble qui contient deux listes, que se passe-t-il et pourquoi ?

# %% [markdown]
# ### Exercice 20 -  Vrai ou faux
#
# Dis si les affirmations suivantes sont vraies ou fausses :
#
# 1. Un set conserve l’ordre d’insertion
# 2. Un set accepte les doublons
# 3. On peut utiliser in avec un set
# 4. discard() peut provoquer une erreur si l’élément n’existe pas
# 5. frozenset est modifiable

# %% [markdown]
# ### Exercice 21 - Mini projet
#
# Écris un programme qui :
#
# 1. demande à l’utilisateur d’entrer une série de mots séparés par des espaces
# 2. convertit ces mots en set
# 3. affiche les mots uniques
# 4. affiche le nombre de mots uniques
# 5. vérifie si le mot "python" est présent

# %% [markdown]
# ## Exercices mêlants plusieurs types de structures
#
# ### Exercice A
#
# Pour les étudiants suivants :
#
# 1. Calculer la moyenne de chaque étudiant
# 2. Ajouter à chaque étudiant sa moyenne ("average")
# 3. Trouver l’étudiant avec la meilleure moyenne
# 4. Créer une liste des étudiants ayant une moyenne supérieure ou égale à 12

# %%
students = [
    {"name": "Alice", "grades": [12, 15, 14]},
    {"name": "Bob", "grades": [9, 11, 10]},
    {"name": "Charlie", "grades": [16, 17, 15]}
]

# %% [markdown]
# ### Exercice B
#
# À partir des données suivantes :
#
# 1. Calculer le total des ventes
# 2. Trouver le jour avec le maximum de ventes
# 3. Calculer la moyenne
# 4. Créer un dictionnaire {jour: vente}
# 5. Trouver les jours où les ventes sont supérieures à la moyenne

# %%
sales = [
    ("lundi", 120),
    ("mardi", 340),
    ("mercredi", 560),
    ("jeudi", 230),
    ("vendredi", 150)
]

# %% [markdown]
# ### Exercice C
#
# À partir des données suivantes :
#
# 1. Transformer le texte en liste de mots
# 2. Créer un set des mots uniques
# 3. Compter le nombre d’occurrences de chaque mot (dictionnaire)
# 4. Trouver le mot le plus fréquent
# 5. Trouver les mots qui apparaissent une seule fois

# %%
text = "data science is fun and data science is powerful"

# %% [markdown]
# ### Exercice D
#
# À partir des données suivantes :
#
# 1. Trouver toutes les compétences existantes
# 2. Trouver les personnes qui connaissent "python"
# 3. Trouver les compétences communes à tous
# 4. Trouver les compétences uniques à chaque personne
# 5. Trouver les personnes qui ont au moins 2 compétences en commun

# %%
people = [
    {"name": "Alice", "skills": {"python", "data", "ml"}},
    {"name": "Bob", "skills": {"excel", "data"}},
    {"name": "Charlie", "skills": {"python", "ml"}},
    {"name": "David", "skills": {"python", "excel"}}
]

# %% [markdown]
# ### Exercice E
#
# À partir des données suivantes :
#
# 1. Trouver tous les produits uniques
# 2. Compter combien de fois chaque produit est vendu
# 3. Trouver le produit le plus vendu
# 4. Trouver les commandes contenant "apple"
# 5. Créer un dictionnaire {produit: nombre de commandes distinctes}

# %%
orders = [
    {"id": 1, "items": ["apple", "banana", "apple"]},
    {"id": 2, "items": ["banana", "orange"]},
    {"id": 3, "items": ["apple", "orange", "banana", "banana"]}
]

# %% [markdown]
# ### Exercice F
#
# À partir des données suivantes :
#
# 1. Compter le nombre total d’actions
# 2. Compter les occurrences de chaque type d’action
# 3. Trouver l’utilisateur le plus actif
# 4. Trouver les utilisateurs ayant fait plus de 2 actions
# 5. Trouver les actions uniques par utilisateur

# %%
data = [
    {"user": "Alice", "actions": ["click", "view", "click"]},
    {"user": "Bob", "actions": ["view"]},
    {"user": "Charlie", "actions": ["click", "click", "view"]}
]
