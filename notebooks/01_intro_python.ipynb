# %% [markdown]
# # Python for Data Science
#
# ## Notebook 01 – Introduction à Python
#
# Objectifs de ce notebook :
#
# - comprendre la syntaxe Python
# - manipuler les structures de données
# - écrire des boucles simples
# - découvrir la manipulation de données avec Pandas

# %%
# Premier programme Python

print("Hello Python!")
# Out:
# Hello Python!

# %% [markdown]
# ## Variables
#
# Une variable permet de stocker une valeur.

# %%
x = 5
y = 10

print(x + y)
# Out:
# 15
